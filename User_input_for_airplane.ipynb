# %% [markdown]
# <a href="https://colab.research.google.com/github/suk404/Sukriti-Khanal/blob/main/User_input_for_airplane.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
no_planes = 5
planes = [1, 2, 3, 4, 5]
A = "Land the plane"
B = "Reduce Fuel"
C = "Quit Program"
plane_fuel = {1: 100, 2: 100, 3: 100, 4: 100, 5: 100}

def plane_landing(plane_number):
    print("Plane", plane_number, "has landed")
    file1.write("Plane " + str(plane_number) + " has landed\n")
    print("-" * 150)

def reduce_fuel(no_reduction):
    show_planes()
    for i in range(no_reduction):
        reduce_plane_fuel = int(input("Which planes should reduce their fuel "))
        file1.write("Which planes should reduce their fuel " + str(reduce_plane_fuel) + "\n")
        print("-" * 150)
        if reduce_plane_fuel not in plane_fuel.keys():
            print("Invalid input. Enter it again")
            reduce_plane_fuel = int(input("Which planes should reduce their fuel "))
            print("-" * 150)

        fuel_reduction_level = int(input("How much do you want to reduce it? "))
        file1.write("How much do you want to reduce it? " + str(fuel_reduction_level) + "\n")
        print("-" * 150)
        if fuel_reduction_level > 100:
            print("Invalid input. Enter it again")
            fuel_reduction_level = int(input("How much do you want to reduce it? "))

        print("Plane", reduce_plane_fuel, "Fuel level reduced by", fuel_reduction_level, "Gallons")
        file1.write("Plane " + str(reduce_plane_fuel) + " Fuel level reduced by " + str(fuel_reduction_level) + " Gallons\n")
        plane_fuel[reduce_plane_fuel] = plane_fuel.get(reduce_plane_fuel) - fuel_reduction_level
        print("-" * 150)

def show_planes():
    for key, value in plane_fuel.items():
        print("Plane", key, "- Fuel Level", value, "Gallons")
        file1.write("Plane " + str(key) + "- Fuel Level " + str(value) + " Gallons\n")

while no_planes <= 5 and no_planes > 0:
    file1 = open('FlightSimulator55.txt', 'a')  # Open the file in 'append' mode
    print("There are", no_planes, "planes in the Sky.")
    file1.write("There are " + str(no_planes) + " planes in the Sky\n ")
    print("A. ", A)
    file1.write("A. " + A + "\n")
    print("B. ", B)
    file1.write("B. " + B + "\n")
    print("C. ", C)
    file1.write("C. " + C + "\n")
    user_input = input("Enter your choice: ")
    file1.write("You entered " + str(user_input) + "\n")
    print("-" * 150)
    file1.writelines("-" * 150 + "\n")

    if user_input == 'A' or user_input == 'a':
        show_planes()
        user_plane_land = int(input("Which plane should land? "))
        file1.write("Which plane should land? " + str(user_plane_land) + "\n")
        print("-" * 150)
        file1.write("-" * 150 + "\n")
        if user_plane_land not in plane_fuel.keys():
            print("Invalid input. Enter it again")
            user_plane_land = int(input("Which plane should land? "))
            print("-" * 150)

        plane_landing(user_plane_land)
        planes.remove(user_plane_land)
        no_planes =no_planes- 1

    elif user_input == 'B' or user_input == 'b':
        print("-" * 150)
        show_planes()
        user_fuel_reduction = int(input("How many planes should have their fuel level reduced "))
        file1.write("How many planes should have their fuel level reduced " + str(user_fuel_reduction) + "\n")
        print("-" * 150)
        file1.write("-" * 150 + "\n")
        if user_fuel_reduction >= no_planes:
            print("Invalid Input. Enter it again")
            user_fuel_reduction = int(input("How many planes should have their fuel level reduced "))

        reduce_fuel(user_fuel_reduction)

    elif user_input == "C" or user_input == 'c':
        break

    else:
        print("Invalid input. Enter it again")
        user_input = input("Enter your choice: ")

file1.close()
# Out:
# There are 5 planes in the Sky.
# A.  Land the plane
# B.  Reduce Fuel
# C.  Quit Program
# Enter your choice: a
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Plane 1 - Fuel Level 100 Gallons
# Plane 2 - Fuel Level 100 Gallons
# Plane 3 - Fuel Level 100 Gallons
# Plane 4 - Fuel Level 100 Gallons
# Plane 5 - Fuel Level 100 Gallons
# Which plane should land? 3
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Plane 3 has landed
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# There are 4 planes in the Sky.
# A.  Land the plane
# B.  Reduce Fuel
# C.  Quit Program
# Enter your choice: b
# ...

# %%
no_planes = 5
planes = [1, 2, 3, 4, 5]
A = "Land the plane"
B = "Reduce Fuel"
C = "Quit Program"
plane_fuel = {1: 100, 2: 100, 3: 100, 4: 100, 5: 100}

def plane_landing(plane_number):
    print("Plane", plane_number, "has landed")
    file1.write("Plane " + str(plane_number) + " has landed\n")
    print("-" * 150)
    file1.write("-" * 150 + "\n")
    planes.remove(plane_number)
    del plane_fuel[plane_number]
    return planes

def reduce_fuel(no_reduction):
    show_planes()
    for i in range(no_reduction):
        reduce_plane_fuel = int(input("Which planes should reduce their fuel "))
        file1.write("Which planes should reduce their fuel " + str(reduce_plane_fuel) + "\n")
        print("-" * 150)
        file1.write("-" * 150 + "\n")
        if reduce_plane_fuel not in plane_fuel.keys():
            print("Invalid input. Enter it again")
            reduce_plane_fuel = int(input("Which planes should reduce their fuel "))
            print("-" * 150)

        fuel_reduction_level = int(input("How much do you want to reduce it? "))
        file1.write("How much do you want to reduce it? " + str(fuel_reduction_level) + "\n")
        print("-" * 150)
        if fuel_reduction_level > 100:
            print("Invalid input. Enter it again")
            fuel_reduction_level = int(input("How much do you want to reduce it? "))

        print("Plane", reduce_plane_fuel, "Fuel level reduced by", fuel_reduction_level, "Gallons")
        file1.write("Plane " + str(reduce_plane_fuel) + " Fuel level reduced by " + str(fuel_reduction_level) + " Gallons\n")
        plane_fuel[reduce_plane_fuel] = plane_fuel.get(reduce_plane_fuel) - fuel_reduction_level
        print("-" * 150)

def show_planes():
    for key, value in plane_fuel.items():
        print("Plane", key, "- Fuel Level", value, "Gallons")
        file1.write("Plane " + str(key) + "- Fuel Level " + str(value) + " Gallons\n")

while no_planes <= 5 and no_planes > 0:
    file1 = open('FlightSimulator505.txt', 'w')  # Open the file in 'write' mode
    print("There are", no_planes, "planes in the Sky.")
    file1.write("There are " + str(no_planes) + " planes in the Sky\n ")
    print("A. ", A)
    file1.write("A. " + A + "\n")
    print("B. ", B)
    file1.write("B. " + B + "\n")
    print("C. ", C)
    file1.write("C. " + C + "\n")
    user_input = input("Enter your choice: ")
    file1.write("You entered " + str(user_input) + "\n")
    print("-" * 150)
    file1.writelines("-" * 150 + "\n")

    if user_input == 'A' or user_input == 'a':
        show_planes()
        user_plane_land = int(input("Which plane should land? "))
        file1.write("Which plane should land? " + str(user_plane_land) + "\n")
        print("-" * 150)
        file1.write("-" * 150 + "\n")
        if user_plane_land not in plane_fuel.keys():
            print("Invalid input. Enter it again")
            user_plane_land = int(input("Which plane should land? "))
            print("-" * 150)

        plane_landing(user_plane_land)

        no_planes -= 1

    elif user_input == 'B' or user_input == 'b':
        print("-" * 150)
        show_planes()
        user_fuel_reduction = int(input("How many planes should have their fuel level reduced "))
        file1.write("How many planes should have their fuel level reduced " + str(user_fuel_reduction) + "\n")
        print("-" * 150)
        file1.write("-" * 150 + "\n")
        if user_fuel_reduction >= no_planes:
            print("Invalid Input. Enter it again")
            user_fuel_reduction = int(input("How many planes should have their fuel level reduced "))

        reduce_fuel(user_fuel_reduction)

    elif user_input == "C" or user_input == 'c':
        break

    else:
        print("Invalid input. Enter it again")
        user_input = input("Enter your choice: ")

file1.close()
# Out:
# There are 5 planes in the Sky.
# A.  Land the plane
# B.  Reduce Fuel
# C.  Quit Program
# Enter your choice: a
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Plane 1 - Fuel Level 100 Gallons
# Plane 2 - Fuel Level 100 Gallons
# Plane 3 - Fuel Level 100 Gallons
# Plane 4 - Fuel Level 100 Gallons
# Plane 5 - Fuel Level 100 Gallons
# Which plane should land? 3
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Plane 3 has landed
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# There are 4 planes in the Sky.
# A.  Land the plane
# B.  Reduce Fuel
# C.  Quit Program
# Enter your choice: b
# ...

# %%
no_planes = 5
planes = [1, 2, 3, 4, 5]
A = "Land the plane"
B = "Reduce Fuel"
C = "Quit Program"
plane_fuel = {1: 100, 2: 100, 3: 100, 4: 100, 5: 100}

def plane_landing(plane_number):
    print("Plane", plane_number, "has landed")
    file1.write("Plane " + str(plane_number) + " has landed\n")
    planes.remove(plane_number)
    del plane_fuel[plane_number]

def reduce_fuel(no_reduction):
    show_planes()
    for i in range(no_reduction):
        reduce_plane_fuel = int(input("Which planes should reduce their fuel "))
        if reduce_plane_fuel not in plane_fuel.keys():
            print("Invalid input. Enter it again")
            reduce_plane_fuel = int(input("Which planes should reduce their fuel "))

        fuel_reduction_level = int(input("How much do you want to reduce it? "))
        if fuel_reduction_level > 100:
            print("Invalid input. Enter it again")
            fuel_reduction_level = int(input("How much do you want to reduce it? "))

        print("Plane", reduce_plane_fuel, "Fuel level reduced by", fuel_reduction_level, "Gallons")
        file1.write("Plane " + str(reduce_plane_fuel) + " Fuel level reduced by " + str(fuel_reduction_level) + " Gallons\n")
        plane_fuel[reduce_plane_fuel] = plane_fuel.get(reduce_plane_fuel) - fuel_reduction_level

def show_planes():
    for key, value in plane_fuel.items():
        print("Plane", key, "- Fuel Level", value, "Gallons")

while no_planes <= 5 and no_planes > 0:
    file1 = open('FlightSimulator565.txt', 'a')  # Open the file in 'append' mode
    print("There are", no_planes, "planes in the Sky.")
    file1.write("There are " + str(no_planes) + " planes in the Sky\n ")
    print("A. ", A)
    file1.write("A. " + A + "\n")
    print("B. ", B)
    file1.write("B. " + B + "\n")
    print("C. ", C)
    file1.write("C. " + C + "\n")
    user_input = input("Enter your choice: ")
    file1.write("You entered " + str(user_input) + "\n")

    if user_input == 'A' or user_input == 'a':
        show_planes()
        user_plane_land = int(input("Which plane should land? "))
        if user_plane_land not in plane_fuel.keys():
            print("Invalid input. Enter it again")
            user_plane_land = int(input("Which plane should land? "))

        plane_landing(user_plane_land)

        no_planes -= 1

    elif user_input == 'B' or user_input == 'b':
        show_planes()
        user_fuel_reduction = int(input("How many planes should have their fuel level reduced "))
        if user_fuel_reduction >= no_planes:
            print("Invalid Input. Enter it again")
            user_fuel_reduction = int(input("How many planes should have their fuel level reduced "))

        reduce_fuel(user_fuel_reduction)

    elif user_input == "C" or user_input == 'c':
        break

    else:
        print("Invalid input. Enter it again")
        user_input = input("Enter your choice: ")

file1.close()
# Out:
# There are 5 planes in the Sky.
# A.  Land the plane
# B.  Reduce Fuel
# C.  Quit Program
# Enter your choice: a
# Plane 1 - Fuel Level 100 Gallons
# Plane 2 - Fuel Level 100 Gallons
# Plane 3 - Fuel Level 100 Gallons
# Plane 4 - Fuel Level 100 Gallons
# Plane 5 - Fuel Level 100 Gallons
# Which plane should land? 3
# Plane 3 has landed
# There are 4 planes in the Sky.
# A.  Land the plane
# B.  Reduce Fuel
# C.  Quit Program
# Enter your choice: b
# Plane 1 - Fuel Level 100 Gallons
# Plane 2 - Fuel Level 100 Gallons
# Plane 4 - Fuel Level 100 Gallons
# Plane 5 - Fuel Level 100 Gallons
# How many planes should have their fuel level reduced 2
# Plane 1 - Fuel Level 100 Gallons
# Plane 2 - Fuel Level 100 Gallons
# Plane 4 - Fuel Level 100 Gallons
# Plane 5 - Fuel Level 100 Gallons
# Which planes should reduce their fuel 2
# How much do you want to reduce it? 15
# Plane 2 Fuel level reduced by 15 Gallons
# Which planes should reduce their fuel 5
# How much do you want to reduce it? 15
# ...
